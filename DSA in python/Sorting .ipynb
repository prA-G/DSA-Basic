# %% [markdown]
# # Sorting

# %% [markdown]
# Sorting is the process of arranging data in a particular order, usually ascending (small → large) or descending (large → small).
#
# It’s like arranging your books on a shelf from shortest to tallest or lining up your friends from youngest to oldest. 📚👫

# %% [markdown]
# ## Why Sorting is Important?
#
# - Helps in searching efficiently (like binary search). 🔍
#
# - Makes data organized and readable.
#
# - Essential for DSA problems like finding pairs, duplicates, or max/min efficiently.

# %% [markdown]
# ## Sorting Table

# %% [markdown]
# | Sorting Method      | Concept                                                                              | Pythonic Example              |
# | ------------------- | ------------------------------------------------------------------------------------ | ----------------------------- |
# | **Bubble Sort**     | Compare adjacent elements and swap if out of order; repeat.                          | See below                     |
# | **Selection Sort**  | Find the minimum (or maximum) and place it at the correct position.                  | See below                     |
# | **Insertion Sort**  | Pick an element and insert it at its correct position among already sorted elements. | See below                     |
# | **Python Built-in** | Python’s `sort()` or `sorted()` use TimSort internally (super efficient).            | `arr.sort()` or `sorted(arr)` |

# %% [markdown]
# ## Bubble Sort

# %% [markdown]
# Compare adjacent elements, swap if they’re in the wrong order, and keep “bubbling” the biggest ones to the end with each pass.
#
# **Key facts**
#
# - Stable (equal items keep order)
#
# - In-place (O(1) extra space)
#
# - Best case O(n) if already sorted (with early-exit check)
#
# - Worst/Average O(n²)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]  # Swap
    return arr

nums = [5, 2, 9, 1, 5]
print(bubble_sort(nums))  # Output: [1, 2, 5, 5, 9]
# Out:
# [1, 2, 5, 5, 9]

# %% [markdown]
# Intuition: Big numbers “bubble up” to the end. 🛁💨

# %% [markdown]
# ## Selection Sort

# %% [markdown]
# Repeatedly pick the minimum (or maximum) from the unsorted portion and place it at the next position in the sorted portion.
# Think: pick the smallest book from the pile and put it at the leftmost empty spot — rinse & repeat.
#
# **Properties**
#
# - In-place: O(1) extra space
#
# - Not stable by default (equal items can change order) — but you can implement a stable variant.
#
# - Time: O(n²) always (doesn’t get faster if array is nearly sorted)
#
# - Use-case: educational, tiny arrays, or when memory is super tight.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i+1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr

nums = [64, 25, 12, 22, 11]
print(selection_sort(nums))  # Output: [11, 12, 22, 25, 64]
# Out:
# [11, 12, 22, 25, 64]

# %% [markdown]
# Intuition: Pick the smallest remaining element and put it in the correct place. 🏆

# %% [markdown]
# ## Insertion Sort

# %% [markdown]
# Insertion Sort is a simple, comparison-based sorting algorithm where elements are picked one by one from the unsorted portion and inserted into their correct position in the sorted portion of the array (just like sorting cards in your hand).
#
# **Properties**
#
# - Stable, in-place, adaptive (fast on nearly-sorted arrays).
#
# - Best: O(n) (already sorted with minimal checks) — with swaps/shifts O(n) each step in worst case.
#
# - Average/Worst: O(n²).
#
# - Space: O(1).

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i-1
        while j >= 0 and arr[j] > key:
            arr[j+1] = arr[j]
            j -= 1
        arr[j+1] = key
    return arr

nums = [12, 11, 13, 5, 6]
print(insertion_sort(nums))  # Output: [5, 6, 11, 12, 13]
# Out:
# [5, 6, 11, 12, 13]

# %% [markdown]
# Intuition: Take one element at a time and insert it into the right place among sorted elements. ✨

# %% [markdown]
# ## Pythonic Way

# %%
nums = [3, 1, 4, 1, 5, 8]
sorted_nums = sorted(nums)  # Returns a new sorted list
nums.sort()                  # Sorts the list in-place
print(sorted_nums)  # [1, 1, 3, 4, 5, 9]
print(nums)         # [1, 1, 3, 4, 5, 9]
# Out:
# [1, 1, 3, 4, 5, 8]
# [1, 1, 3, 4, 5, 8]

# %% [markdown]
# Intuition: Python handles it all for you with TimSort — efficient and elegant. 💖

# %% [markdown]
# # Time Complexity

# %% [markdown]
# | Algorithm       | Best Case | Worst Case | Space |
# | --------------- | --------- | ---------- | ----- |
# | Bubble Sort     | O(n)      | O(n²)      | O(1)  |
# | Selection Sort  | O(n²)     | O(n²)      | O(1)  |
# | Insertion Sort  | O(n)      | O(n²)      | O(1)  |
# | Python `sort()` | O(n)      | O(n log n) | O(n)  |
